# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\placement_placed.csv")

# %%
print(df.shape)
df.head()
# Trying  to predict Placed using perceptron technique
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(df['cgpa'],df['resume_score'],hue=df['placed'])
# plotting the data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.scatterplot(df['cgpa'],df['resume_score'],hue=df['placed'])
#       2 # plotting the data
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
X = df.iloc[:,0:2] # x...all rows and col cgpa and resume_score
y = df.iloc[:,-1]  # y

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()  # perceptron object

# %%
p.fit(X,y)
Perceptron()
# Out:
# Perceptron()

# %%
p.coef_
# coef are the weights
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# intercept is bias
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
